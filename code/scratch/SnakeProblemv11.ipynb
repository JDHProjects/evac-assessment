# %% [markdown]
# This version of the snake game allows you to implement and run your evolutionary algorithm

# %%
import random
import time
import turtle
import numpy as np
import math

# %%
# Number of grid cells in each direction (do not change this)
XSIZE = YSIZE = 16

# %% [markdown]
# Change headless to True when evolving your solution. You can then pickle your final solution, and run it with this set to True to visualize the result, if you wish. Note that, when using Turtle, to run it again properly you might need to go to restart your kernel after the visualization has finished.

# %% [markdown]
# If you are running on the cloud, or on Google Colab, you can chose to remove the turtle and display code altogether and only run headless. You could then pickle your best solution and use this code to see it play.

# %%
HEADLESS = True
QUIET = True

# %%
class DisplayGame:
  def __init__( self, XSIZE, YSIZE):
    # SCREEN
    self.win = turtle.Screen()
    self.win.title("EVCO Snake game")
    self.win.bgcolor("grey")
    self.win.setup(width=(XSIZE*20)+40, height=(YSIZE*20)+40)
    # self.win.screensize((XSIZE*20)+20,(YSIZE*20)+20)
    self.win.tracer(0)

    # Snake Head
    self.head = turtle.Turtle()
    self.head.shape("square")
    self.head.color("black")

    # Snake food
    self.food = turtle.Turtle()
    self.food.shape("circle")
    self.food.color("yellow")
    self.food.penup()
    self.food.shapesize(0.55, 0.55)
    self.segments = []

  def reset(self, snake):
    self.segments = []
    self.head.penup()
    self.food.goto(-500, -500)
    self.head.goto(-500, -500)
    for i in range(len(snake)-1):
      self.add_snake_segment()
    self.update_segment_positions(snake)

  def update_food(self, new_food):
    self.food.goto(((new_food[1]-9)*20)+20, (((9-new_food[0])*20)-10)-20)

  def update_segment_positions(self, snake):
    self.head.goto(((snake[0][1]-9)*20)+20, (((9-snake[0][0])*20)-10)-20)
    for i in range(len(self.segments)):
      self.segments[i].goto(((snake[i+1][1]-9)*20)+20,
                            (((9-snake[i+1][0])*20)-10)-20)

  def add_snake_segment(self):
    self.new_segment = turtle.Turtle()
    self.new_segment.speed(0)
    self.new_segment.shape("square")
    # random.choice(["green", 'black', 'red', 'blue']))
    self.new_segment.color("green")
    self.new_segment.penup()
    self.segments.append(self.new_segment)

# %%
class snake:
  def __init__(self, _XSIZE, _YSIZE):
    self.XSIZE = _XSIZE
    self.YSIZE = _YSIZE
    self.reset()

  def reset(self):
    self.snake = [[8, 10], [8, 9], [8, 8], [8, 7], [8, 6], [8, 5], [8, 4], [
        8, 3], [8, 2], [8, 1], [8, 0]]  # Initial snake co-ordinates [ypos,xpos]
    self.food = self.place_food()
    self.snake_direction = "right"

  def place_food(self):
    self.food = [random.randint(1, (YSIZE-2)),
                 random.randint(1, (XSIZE-2))]
    while (self.food in self.snake):
      self.food = [random.randint(
          1, (YSIZE-2)), random.randint(1, (XSIZE-2))]
    return(self.food)

  def update_snake_position(self):
    self.snake.insert(0, [self.snake[0][0] + (self.snake_direction == "down" and 1) + (self.snake_direction == "up" and -1),
                      self.snake[0][1] + (self.snake_direction == "left" and -1) + (self.snake_direction == "right" and 1)])

  def food_eaten(self):
    # When snake eats the food
    if self.snake[0] == self.food:
      return True
    else:
      # [1] If it does not eat the food, it moves forward and so last tail item is removed
      last = self.snake.pop()
      return False

  def snake_turns_into_self(self):
    if self.snake[0] in self.snake[1:]:
      return True
    else:
      return False

  def snake_hit_wall(self):
    if self.snake[0][0] == 0 or self.snake[0][0] == (YSIZE-1) or self.snake[0][1] == 0 or self.snake[0][1] == (XSIZE-1):
      return True
    else:
      return False

  def manhattanDistance(self, pos):
    return abs(pos[0]-self.food[0])+abs(pos[1]-self.food[1])

  def senseWall(self, pos):
    return(pos[0] < 0 or pos[0] > (YSIZE-1) or pos[1] < 0 or pos[1] > (XSIZE-1))

  def senseTail(self, pos):
    return pos in self.snake[:-1]


  def leftWall(self):
    return self.senseWall([self.snake[0][0],self.snake[0][1]-1])

  def leftTail(self):
    return self.senseTail([self.snake[0][0],self.snake[0][1]-1])

  def leftFood(self):
    return self.food[1] < self.snake[0][1]

  def rightWall(self):
    return self.senseWall([self.snake[0][0],self.snake[0][1]+1])

  def rightTail(self):
    return self.senseTail([self.snake[0][0],self.snake[0][1]+1])

  def rightFood(self):
    return self.food[1] > self.snake[0][1]

  def upWall(self):
    return self.senseWall([self.snake[0][0]-1,self.snake[0][1]])

  def upTail(self):
    return self.senseTail([self.snake[0][0]-1,self.snake[0][1]])

  def upFood(self):
    return self.food[0] < self.snake[0][0]

  def downWall(self):
    return self.senseWall([self.snake[0][0]+1,self.snake[0][1]])

  def downTail(self):
    return self.senseTail([self.snake[0][0]+1,self.snake[0][1]])

  def downFood(self):
    return self.food[0] > self.snake[0][0]

  def leftSpace(self):
    return self.getSpaceAtPoint(self.snake[0][0],self.snake[0][1]-1)

  def rightSpace(self):
    return self.getSpaceAtPoint(self.snake[0][0],self.snake[0][1]+1)

  def upSpace(self):
    return self.getSpaceAtPoint(self.snake[0][0]-1,self.snake[0][1])

  def downSpace(self):
    return self.getSpaceAtPoint(self.snake[0][0]+1,self.snake[0][1])

  def getSpaceAtPoint(self, y, x):
    if(self.senseWall([y,x]) or self.senseTail([y,x])):
      return 0
    search = []
    for _ in range(0,YSIZE):
      xList = []
      for _ in range(0,XSIZE):
        xList.append(0)
      search.append(xList)

    for segment in self.snake:
      search[segment[0]][segment[1]] = 1

    counter, _ = self.searchSpace(y,x, search)
    return counter

  def searchSpace(self, y, x, searched):
    if ( y < 0 or y >= len(searched) or x < 0 or x >= len(searched[y]) or searched[y][x] == 1):
      return 0, searched
    searched[y][x] = 1
    #right
    right, searched = self.searchSpace(y,x+1, searched)
    #left
    left, searched = self.searchSpace(y,x-1, searched)
    #down
    down, searched = self.searchSpace(y+1,x, searched)
    #up
    up, searched = self.searchSpace(y-1,x, searched)
    return right+left+down+up+1, searched


  def getDistanceToFood(self):
    return math.sqrt((abs(self.food[0]-self.snake[0][0]) ** 2) + (abs(self.food[1]-self.snake[0][1]) ** 2))

# %%
snake_game = snake(XSIZE, YSIZE)

# %%
if not HEADLESS:
  display = DisplayGame(XSIZE, YSIZE)

# %%
def run_game(network, display, snake_game, headless):

  score = 0
  timeAlive = 0
  timeSinceNom = 0
  snake_game.reset()
  if not headless:
    display.reset(snake_game.snake)
    display.win.update()
  snake_game.place_food()
  game_over = False

  while not game_over:
    timeAlive+=1
    timeSinceNom+=1
    # ****YOUR AI BELOW HERE******************

    inputs = [  snake_game.leftWall(), snake_game.leftTail(), snake_game.leftFood(),
                snake_game.rightWall(), snake_game.rightTail(), snake_game.rightFood(),
                snake_game.upWall(), snake_game.upTail(), snake_game.upFood(),
                snake_game.downWall(), snake_game.downTail(), snake_game.downFood(),
                ]
    #print(inputs)
    output = network.feedForward(inputs)
    decision = np.argmax(output, axis=0)
    if decision == 0:
      snake_game.snake_direction = "left"
    elif decision == 1:
      snake_game.snake_direction = "right"
    elif decision == 2:
      snake_game.snake_direction = "up"
    elif decision == 3:
      snake_game.snake_direction = "down"

    # ****YOUR AI ABOVE HERE******************

    snake_game.update_snake_position()

    # Check if food is eaten
    if snake_game.food_eaten():
      timeSinceNom=0
      snake_game.place_food()
      score += 1
      if not headless:
        display.add_snake_segment()

    # Game over if the snake runs over itself
    if snake_game.snake_turns_into_self():
      game_over = True
      #print("Snake turned into itself!")

    # Game over if the snake goes through a wall
    if snake_game.snake_hit_wall():
      game_over = True
      #print("Snake hit a wall!")
    if(timeSinceNom > 50):
      timeAlive-=50
      game_over = True
    #if(timeAlive % 50 == 0):
      
    if not headless:
      display.update_food(snake_game.food)
      display.update_segment_positions(snake_game.snake)
      display.win.update()
      # Change this to modify the speed the game runs at when displayed.
      time.sleep(0.2)

  if not headless:
    turtle.done()
    try:
      turtle.bye()
    except turtle.Terminator:
      pass
    print("\nFINAL score - " +  str(score))

  #boardHyp = math.sqrt(XSIZE ** 2 + YSIZE ** 2)
  # score  + ((boardHyp - snake_game.getDistanceToFood()) / boardHyp)
  
  return (score ** 2) * timeAlive, score

# %%
class MLP(object):
  def __init__(self, numInput, numHidden1, numHidden2, numOutput):
    self.fitness = 0
    self.numInput = numInput + 1  # Add bias node from input to hidden layer 1 only
    # Feel free to adapt the code to add more biases if you wish
    self.numHidden1 = numHidden1
    self.numHidden2 = numHidden2
    self.numOutput = numOutput

    self.w_i_h1 = np.random.randn(self.numHidden1, self.numInput)
    self.w_h1_h2 = np.random.randn(self.numHidden2, self.numHidden1)
    self.w_h2_o = np.random.randn(self.numOutput, self.numHidden2)

    self.ReLU = lambda x: max(0, x)

  def softmax(self, x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum()

  def feedForward(self, inputs):
    inputsBias = inputs[:]
    inputsBias.insert(len(inputs), 1)             # Add bias input

    # feed input to hidden layer 1
    h1 = np.dot(self.w_i_h1, inputsBias)
    h1 = [self.ReLU(x) for x in h1]              # Activate hidden layer1

    # feed layer 1 to hidden layer 2
    h2 = np.dot(self.w_h1_h2, h1)
    h2 = [self.ReLU(x) for x in h2]              # Activate hidden layer 2

    output = np.dot(self.w_h2_o, h2)             # feed to output layer
    # output = [self.sigmoid(x) for x in output]   # Activate output layer
    return self.softmax(output)

  def getWeightsLinear(self):
    flat_w_i_h1 = list(self.w_i_h1.flatten())
    flat_w_h1_h2 = list(self.w_h1_h2.flatten())
    flat_w_h2_o = list(self.w_h2_o.flatten())
    return(flat_w_i_h1 + flat_w_h1_h2 + flat_w_h2_o)

  def setWeightsLinear(self, Wgenome):
    numWeights_I_H1 = self.numHidden1 * self.numInput
    numWeights_H1_H2 = self.numHidden2 * self.numHidden1
    numWeights_H2_O = self.numOutput * self.numHidden2

    self.w_i_h1 = np.array(Wgenome[:numWeights_I_H1])
    self.w_i_h1 = self.w_i_h1.reshape((self.numHidden1, self.numInput))

    self.w_h1_h2 = np.array(
        Wgenome[numWeights_I_H1:(numWeights_H1_H2+numWeights_I_H1)])
    self.w_h1_h2 = self.w_h1_h2.reshape((self.numHidden2, self.numHidden1))

    self.w_h2_o = np.array(Wgenome[(numWeights_H1_H2+numWeights_I_H1):])
    self.w_h2_o = self.w_h2_o.reshape((self.numOutput, self.numHidden2))

# %%
from deap import base
from deap import creator
from deap import tools
from datetime import datetime

random.seed(datetime.now())  # Set a random seed from the clock

numInputNodes = 12
numHiddenNodes1 = 12
numHiddenNodes2 = 12
numOutputNodes = 4

IND_SIZE = ((numInputNodes+1) * numHiddenNodes1) + (numHiddenNodes1 *
                                                    numHiddenNodes2) + (numHiddenNodes2 * numOutputNodes)

network = MLP(numInputNodes, numHiddenNodes1, numHiddenNodes2, numOutputNodes)


creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, -1.0, 1.0)
toolbox.register("individual", tools.initRepeat, creator.Individual,
                 toolbox.attr_float, n=IND_SIZE)

toolbox.register("mate", tools.cxOnePoint)


def evaluate(indiv, network):
  fitness = 0
  network.setWeightsLinear(indiv)
  fitness,score = run_game(network, display, snake_game, headless=HEADLESS)
  return ((fitness,), score)


toolbox.register("evaluate", evaluate)


toolbox.register("select", tools.selRoulette)


toolbox.register("mutate", tools.mutGaussian, mu=0.0, sigma=0.5, indpb=0.05)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)


stats = tools.Statistics(key=lambda ind: ind.fitness.values)
stats.register("avg", np.mean)
stats.register("std", np.std)
stats.register("min", np.min)
stats.register("max", np.max)


logbook = tools.Logbook()


NGEN = 1000
CXPB = 0
MUTPB = 1
POP = 200

pop = toolbox.population(n=POP)
fitnesses = []
scores = []
for indiv in pop:
  fitness, score = toolbox.evaluate(indiv, network)
  fitnesses.append(fitness)
  scores.append(score)
for ind, fit in zip(pop, fitnesses):
  ind.fitness.values = fit

for g in range(NGEN):
  print("-- Generation %i --" % g)

  besthalf = tools.selBest(pop, len(pop) - (len(pop)//2))
  offspring = list(map(toolbox.clone, besthalf+besthalf))

  for child1, child2 in zip(offspring[::2], offspring[1::2]):
    if random.random() < CXPB:
      toolbox.mate(child1, child2)
      del child1.fitness.values
      del child2.fitness.values

  for mutant in offspring:
    if random.random() < MUTPB:
      toolbox.mutate(mutant)
      del mutant.fitness.values

  for ind in besthalf:
    del ind.fitness.values

  invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
  fitnesses = []
  scores = []
  for indiv in invalid_ind:
    fitness, score = toolbox.evaluate(indiv, network)
    fitnesses.append(fitness)
    scores.append(score)
  for ind, fit in zip(invalid_ind, fitnesses):
    ind.fitness.values = fit

  pop[:] = offspring
  record = stats.compile(pop)
  logbook.record(gen=g, **record)
  print("Max: " + str(np.max(scores)))
  print("Mean: " + str(np.mean(scores)))
  print("Fitness Max: " + str(record['max']))
  print("Fitness Avg: " + str(record['avg']))
# Out:
# -- Generation 0 --
# Max: 3
# Mean: 0.05
# Fitness Max: 108.0
# Fitness Avg: 1.215
# -- Generation 1 --
# Max: 1
# Mean: 0.01
# Fitness Max: 9.0
# Fitness Avg: 0.08
# -- Generation 2 --
# Max: 1
# Mean: 0.035
# Fitness Max: 13.0
# Fitness Avg: 0.28
# -- Generation 3 --
# Max: 1
# Mean: 0.025
# Fitness Max: 19.0
# Fitness Avg: 0.29
# -- Generation 4 --
# Max: 1
# Mean: 0.035
# Fitness Max: 15.0
# Fitness Avg: 0.345
# -- Generation 5 --
# Max: 1
# Mean: 0.035
# Fitness Max: 12.0
# Fitness Avg: 0.34
# -- Generation 6 --
# Max: 1
# Mean: 0.035
# Fitness Max: 17.0
# Fitness Avg: 0.36
# -- Generation 7 --
# Max: 1
# Mean: 0.025
# Fitness Max: 12.0
# Fitness Avg: 0.24
# -- Generation 8 --
# Max: 1
# Mean: 0.025
# Fitness Max: 13.0
# Fitness Avg: 0.24
# -- Generation 9 --
# Max: 2
# Mean: 0.055
# Fitness Max: 24.0
# Fitness Avg: 0.51
# -- Generation 10 --
# Max: 1
# Mean: 0.03
# Fitness Max: 17.0
# Fitness Avg: 0.285
# -- Generation 11 --
# Max: 1
# Mean: 0.07
# Fitness Max: 28.0
# Fitness Avg: 0.815
# -- Generation 12 --
# Max: 1
# Mean: 0.02
# Fitness Max: 12.0
# Fitness Avg: 0.185
# -- Generation 13 --
# Max: 2
# Mean: 0.045
# Fitness Max: 140.0
# Fitness Avg: 1.015
# -- Generation 14 --
# Max: 2
# Mean: 0.045
# Fitness Max: 60.0
# Fitness Avg: 0.595
# -- Generation 15 --
# Max: 1
# Mean: 0.035
# Fitness Max: 15.0
# Fitness Avg: 0.345
# -- Generation 16 --
# Max: 1
# Mean: 0.05
# Fitness Max: 14.0
# Fitness Avg: 0.49
# -- Generation 17 --
# Max: 1
# Mean: 0.03
# Fitness Max: 17.0
# Fitness Avg: 0.34
# -- Generation 18 --
# Max: 1
# Mean: 0.06
# Fitness Max: 15.0
# Fitness Avg: 0.615
# -- Generation 19 --
# Max: 2
# Mean: 0.055
# Fitness Max: 56.0
# Fitness Avg: 0.63
# -- Generation 20 --
# Max: 1
# Mean: 0.055
# Fitness Max: 19.0
# Fitness Avg: 0.575
# -- Generation 21 --
# Max: 2
# Mean: 0.055
# Fitness Max: 52.0
# Fitness Avg: 0.865
# -- Generation 22 --
# Max: 1
# Mean: 0.075
# Fitness Max: 16.0
# Fitness Avg: 0.7
# -- Generation 23 --
# Max: 2
# Mean: 0.065
# Fitness Max: 56.0
# Fitness Avg: 0.86
# -- Generation 24 --
# Max: 2
# Mean: 0.055
# Fitness Max: 36.0
# Fitness Avg: 0.65
# -- Generation 25 --
# Max: 2
# Mean: 0.085
# Fitness Max: 52.0
# Fitness Avg: 1.07
# -- Generation 26 --
# Max: 1
# Mean: 0.075
# Fitness Max: 17.0
# Fitness Avg: 0.875
# -- Generation 27 --
# Max: 1
# Mean: 0.05
# Fitness Max: 16.0
# Fitness Avg: 0.485
# -- Generation 28 --
# Max: 1
# Mean: 0.055
# Fitness Max: 16.0
# Fitness Avg: 0.515
# -- Generation 29 --
# Max: 1
# Mean: 0.065
# Fitness Max: 18.0
# Fitness Avg: 0.675
# -- Generation 30 --
# Max: 2
# Mean: 0.125
# Fitness Max: 48.0
# Fitness Avg: 1.425
# -- Generation 31 --
# Max: 2
# Mean: 0.145
# Fitness Max: 72.0
# Fitness Avg: 1.86
# -- Generation 32 --
# Max: 4
# Mean: 0.125
# Fitness Max: 336.0
# Fitness Avg: 2.955
# -- Generation 33 --
# Max: 1
# Mean: 0.145
# Fitness Max: 22.0
# Fitness Avg: 1.715
# -- Generation 34 --
# Max: 2
# Mean: 0.14
# Fitness Max: 104.0
# Fitness Avg: 2.47
# -- Generation 35 --
# Max: 2
# Mean: 0.18
# Fitness Max: 92.0
# Fitness Avg: 3.135
# -- Generation 36 --
# Max: 2
# Mean: 0.18
# Fitness Max: 104.0
# Fitness Avg: 2.975
# -- Generation 37 --
# Max: 2
# Mean: 0.2
# Fitness Max: 72.0
# Fitness Avg: 3.065
# -- Generation 38 --
# Max: 3
# Mean: 0.24
# Fitness Max: 180.0
# Fitness Avg: 4.365
# -- Generation 39 --
# Max: 3
# Mean: 0.245
# Fitness Max: 171.0
# Fitness Avg: 4.405
# -- Generation 40 --
# Max: 2
# Mean: 0.3
# Fitness Max: 108.0
# Fitness Avg: 4.47
# -- Generation 41 --
# Max: 2
# Mean: 0.295
# Fitness Max: 68.0
# Fitness Avg: 4.83
# -- Generation 42 --
# Max: 3
# Mean: 0.365
# Fitness Max: 207.0
# Fitness Avg: 6.86
# -- Generation 43 --
# Max: 6
# Mean: 0.315
# Fitness Max: 2052.0
# Fitness Avg: 14.48
# -- Generation 44 --
# Max: 2
# Mean: 0.32
# Fitness Max: 96.0
# Fitness Avg: 5.16
# -- Generation 45 --
# Max: 3
# Mean: 0.345
# Fitness Max: 306.0
# Fitness Avg: 8.03
# -- Generation 46 --
# Max: 3
# Mean: 0.335
# Fitness Max: 324.0
# Fitness Avg: 7.36
# -- Generation 47 --
# Max: 3
# Mean: 0.3
# Fitness Max: 216.0
# Fitness Avg: 5.99
# -- Generation 48 --
# Max: 3
# Mean: 0.39
# Fitness Max: 180.0
# Fitness Avg: 7.4
# -- Generation 49 --
# Max: 5
# Mean: 0.4
# Fitness Max: 1175.0
# Fitness Avg: 15.08
# -- Generation 50 --
# Max: 3
# Mean: 0.315
# Fitness Max: 126.0
# Fitness Avg: 5.46
# -- Generation 51 --
# Max: 4
# Mean: 0.47
# Fitness Max: 416.0
# Fitness Avg: 11.185
# -- Generation 52 --
# Max: 3
# Mean: 0.335
# Fitness Max: 207.0
# Fitness Avg: 6.93
# -- Generation 53 --
# Max: 2
# Mean: 0.31
# Fitness Max: 84.0
# Fitness Avg: 4.98
# -- Generation 54 --
# Max: 3
# Mean: 0.405
# Fitness Max: 189.0
# Fitness Avg: 7.17
# -- Generation 55 --
# Max: 3
# Mean: 0.36
# Fitness Max: 225.0
# Fitness Avg: 6.915
# -- Generation 56 --
# Max: 2
# Mean: 0.42
# Fitness Max: 116.0
# Fitness Avg: 7.895
# -- Generation 57 --
# Max: 3
# Mean: 0.42
# Fitness Max: 243.0
# Fitness Avg: 9.02
# -- Generation 58 --
# Max: 3
# Mean: 0.43
# Fitness Max: 117.0
# Fitness Avg: 8.615
# -- Generation 59 --
# Max: 2
# Mean: 0.31
# Fitness Max: 88.0
# Fitness Avg: 6.055
# -- Generation 60 --
# Max: 3
# Mean: 0.415
# Fitness Max: 198.0
# Fitness Avg: 9.995
# -- Generation 61 --
# Max: 3
# Mean: 0.36
# Fitness Max: 153.0
# Fitness Avg: 6.84
# -- Generation 62 --
# Max: 3
# Mean: 0.415
# Fitness Max: 324.0
# Fitness Avg: 9.93
# -- Generation 63 --
# Max: 2
# Mean: 0.38
# Fitness Max: 112.0
# Fitness Avg: 7.655
# -- Generation 64 --
# Max: 2
# Mean: 0.345
# Fitness Max: 188.0
# Fitness Avg: 7.285
# -- Generation 65 --
# Max: 4
# Mean: 0.36
# Fitness Max: 352.0
# Fitness Avg: 7.78
# -- Generation 66 --
# Max: 2
# Mean: 0.335
# Fitness Max: 64.0
# Fitness Avg: 5.04
# -- Generation 67 --
# Max: 3
# Mean: 0.41
# Fitness Max: 198.0
# Fitness Avg: 8.76
# -- Generation 68 --
# Max: 3
# Mean: 0.435
# Fitness Max: 153.0
# Fitness Avg: 8.105
# -- Generation 69 --
# Max: 3
# Mean: 0.455
# Fitness Max: 261.0
# Fitness Avg: 9.51
# -- Generation 70 --
# Max: 3
# Mean: 0.54
# Fitness Max: 189.0
# Fitness Avg: 12.25
# -- Generation 71 --
# Max: 3
# Mean: 0.465
# Fitness Max: 234.0
# Fitness Avg: 10.18
# -- Generation 72 --
# Max: 3
# Mean: 0.485
# Fitness Max: 162.0
# Fitness Avg: 9.67
# -- Generation 73 --
# Max: 3
# Mean: 0.5
# Fitness Max: 207.0
# Fitness Avg: 11.11
# -- Generation 74 --
# Max: 3
# Mean: 0.475
# Fitness Max: 270.0
# Fitness Avg: 9.685
# -- Generation 75 --
# Max: 6
# Mean: 0.54
# Fitness Max: 2484.0
# Fitness Avg: 23.71
# -- Generation 76 --
# Max: 4
# Mean: 0.48
# Fitness Max: 512.0
# Fitness Avg: 12.485
# -- Generation 77 --
# Max: 3
# Mean: 0.43
# Fitness Max: 450.0
# Fitness Avg: 9.255
# -- Generation 78 --
# Max: 2
# Mean: 0.565
# Fitness Max: 156.0
# Fitness Avg: 10.29
# -- Generation 79 --
# Max: 4
# Mean: 0.535
# Fitness Max: 368.0
# Fitness Avg: 13.2
# -- Generation 80 --
# Max: 2
# Mean: 0.42
# Fitness Max: 120.0
# Fitness Avg: 8.41
# -- Generation 81 --
# Max: 5
# Mean: 0.46
# Fitness Max: 1325.0
# Fitness Avg: 14.67
# -- Generation 82 --
# Max: 3
# Mean: 0.42
# Fitness Max: 216.0
# Fitness Avg: 9.045
# -- Generation 83 --
# Max: 2
# Mean: 0.47
# Fitness Max: 104.0
# Fitness Avg: 8.19
# -- Generation 84 --
# Max: 4
# Mean: 0.465
# Fitness Max: 688.0
# Fitness Avg: 14.615
# -- Generation 85 --
# Max: 4
# Mean: 0.55
# Fitness Max: 624.0
# Fitness Avg: 16.47
# -- Generation 86 --
# Max: 4
# Mean: 0.455
# Fitness Max: 464.0
# Fitness Avg: 11.73
# -- Generation 87 --
# Max: 8
# Mean: 0.6
# Fitness Max: 5696.0
# Fitness Avg: 48.245
# -- Generation 88 --
# Max: 5
# Mean: 0.605
# Fitness Max: 925.0
# Fitness Avg: 21.695
# -- Generation 89 --
# Max: 4
# Mean: 0.615
# Fitness Max: 688.0
# Fitness Avg: 18.05
# -- Generation 90 --
# Max: 10
# Mean: 0.645
# Fitness Max: 10100.0
# Fitness Avg: 67.515
# -- Generation 91 --
# Max: 9
# Mean: 0.65
# Fitness Max: 9234.0
# Fitness Avg: 82.325
# -- Generation 92 --
# Max: 5
# Mean: 0.75
# Fitness Max: 1475.0
# Fitness Avg: 45.865
# -- Generation 93 --
# Max: 6
# Mean: 0.61
# Fitness Max: 3276.0
# Fitness Avg: 39.575
# -- Generation 94 --
# Max: 4
# Mean: 0.645
# Fitness Max: 944.0
# Fitness Avg: 22.21
# -- Generation 95 --
# Max: 6
# Mean: 0.595
# Fitness Max: 2988.0
# Fitness Avg: 29.91
# -- Generation 96 --
# Max: 6
# Mean: 0.705
# Fitness Max: 2124.0
# Fitness Avg: 55.51
# -- Generation 97 --
# Max: 7
# Mean: 0.63
# Fitness Max: 4165.0
# Fitness Avg: 41.48
# -- Generation 98 --
# Max: 6
# Mean: 0.625
# Fitness Max: 936.0
# Fitness Avg: 19.555
# -- Generation 99 --
# Max: 4
# Mean: 0.605
# Fitness Max: 864.0
# Fitness Avg: 20.83
# -- Generation 100 --
# Max: 5
# Mean: 0.685
# Fitness Max: 1200.0
# Fitness Avg: 32.995
# -- Generation 101 --
# Max: 4
# Mean: 0.62
# Fitness Max: 450.0
# Fitness Avg: 24.33
# -- Generation 102 --
# Max: 9
# Mean: 0.74
# Fitness Max: 8019.0
# Fitness Avg: 78.9
# -- Generation 103 --
# Max: 5
# Mean: 0.695
# Fitness Max: 1200.0
# Fitness Avg: 31.815
# -- Generation 104 --
# Max: 9
# Mean: 0.845
# Fitness Max: 6642.0
# Fitness Avg: 114.035
# -- Generation 105 --
# Max: 7
# Mean: 0.82
# Fitness Max: 3773.0
# Fitness Avg: 88.77
# -- Generation 106 --
# Max: 8
# Mean: 0.785
# Fitness Max: 5888.0
# Fitness Avg: 93.745
# -- Generation 107 --
# Max: 7
# Mean: 0.8
# Fitness Max: 3871.0
# Fitness Avg: 50.77
# -- Generation 108 --
# Max: 11
# Mean: 0.805
# Fitness Max: 10043.0
# Fitness Avg: 90.23
# -- Generation 109 --
# Max: 6
# Mean: 0.855
# Fitness Max: 2052.0
# Fitness Avg: 51.24
# -- Generation 110 --
# Max: 8
# Mean: 0.81
# Fitness Max: 3968.0
# Fitness Avg: 77.655
# -- Generation 111 --
# Max: 7
# Mean: 0.865
# Fitness Max: 4606.0
# Fitness Avg: 77.85
# -- Generation 112 --
# Max: 8
# Mean: 0.99
# Fitness Max: 5248.0
# Fitness Avg: 123.19
# -- Generation 113 --
# Max: 10
# Mean: 1.04
# Fitness Max: 10400.0
# Fitness Avg: 162.325
# -- Generation 114 --
# Max: 12
# Mean: 1.135
# Fitness Max: 17136.0
# Fitness Avg: 267.635
# -- Generation 115 --
# Max: 10
# Mean: 1.35
# Fitness Max: 12200.0
# Fitness Avg: 218.24
# -- Generation 116 --
# Max: 9
# Mean: 1.34
# Fitness Max: 9882.0
# Fitness Avg: 289.12
# -- Generation 117 --
# Max: 12
# Mean: 1.105
# Fitness Max: 13824.0
# Fitness Avg: 227.345
# -- Generation 118 --
# Max: 10
# Mean: 1.2
# Fitness Max: 9700.0
# Fitness Avg: 238.965
# -- Generation 119 --
# Max: 16
# Mean: 1.575
# Fitness Max: 45056.0
# Fitness Avg: 592.495
# -- Generation 120 --
# Max: 11
# Mean: 1.345
# Fitness Max: 12705.0
# Fitness Avg: 268.785
# -- Generation 121 --
# Max: 11
# Mean: 1.465
# Fitness Max: 13915.0
# Fitness Avg: 366.985
# -- Generation 122 --
# Max: 8
# Mean: 1.375
# Fitness Max: 7360.0
# Fitness Avg: 187.86
# -- Generation 123 --
# Max: 9
# Mean: 1.48
# Fitness Max: 9801.0
# Fitness Avg: 319.75
# -- Generation 124 --
# Max: 15
# Mean: 1.695
# Fitness Max: 44550.0
# Fitness Avg: 728.11
# -- Generation 125 --
# Max: 11
# Mean: 1.625
# Fitness Max: 12705.0
# Fitness Avg: 336.71
# -- Generation 126 --
# Max: 11
# Mean: 1.73
# Fitness Max: 13673.0
# Fitness Avg: 539.8
# -- Generation 127 --
# Max: 14
# Mean: 1.64
# Fitness Max: 26460.0
# Fitness Avg: 563.415
# -- Generation 128 --
# Max: 8
# Mean: 1.46
# Fitness Max: 4800.0
# Fitness Avg: 184.42
# -- Generation 129 --
# Max: 12
# Mean: 1.78
# Fitness Max: 27936.0
# Fitness Avg: 535.155
# -- Generation 130 --
# Max: 10
# Mean: 1.575
# Fitness Max: 10200.0
# Fitness Avg: 318.19
# -- Generation 131 --
# Max: 12
# Mean: 2.04
# Fitness Max: 17568.0
# Fitness Avg: 528.22
# -- Generation 132 --
# Max: 15
# Mean: 2.185
# Fitness Max: 25650.0
# Fitness Avg: 791.045
# -- Generation 133 --
# Max: 15
# Mean: 2.06
# Fitness Max: 33975.0
# Fitness Avg: 632.995
# -- Generation 134 --
# Max: 19
# Mean: 2.155
# Fitness Max: 78698.0
# Fitness Avg: 870.93
# -- Generation 135 --
# Max: 16
# Mean: 1.965
# Fitness Max: 37888.0
# Fitness Avg: 585.48
# -- Generation 136 --
# Max: 13
# Mean: 2.02
# Fitness Max: 19604.0
# Fitness Avg: 542.86
# -- Generation 137 --
# Max: 11
# Mean: 1.86
# Fitness Max: 18997.0
# Fitness Avg: 472.08
# -- Generation 138 --
# Max: 14
# Mean: 2.19
# Fitness Max: 35868.0
# Fitness Avg: 770.875
# -- Generation 139 --
# Max: 13
# Mean: 2.145
# Fitness Max: 21463.0
# Fitness Avg: 651.395
# -- Generation 140 --
# Max: 16
# Mean: 2.12
# Fitness Max: 43264.0
# Fitness Avg: 765.655
# -- Generation 141 --
# Max: 11
# Mean: 2.5
# Fitness Max: 13915.0
# Fitness Avg: 785.605
# -- Generation 142 --
# Max: 15
# Mean: 2.47
# Fitness Max: 51300.0
# Fitness Avg: 1310.575
# -- Generation 143 --
# Max: 17
# Mean: 2.44
# Fitness Max: 42483.0
# Fitness Avg: 1273.125
# -- Generation 144 --
# Max: 22
# Mean: 2.605
# Fitness Max: 126808.0
# Fitness Avg: 1424.965
# -- Generation 145 --
# Max: 14
# Mean: 2.38
# Fitness Max: 31556.0
# Fitness Avg: 764.86
# -- Generation 146 --
# Max: 15
# Mean: 2.635
# Fitness Max: 39825.0
# Fitness Avg: 1065.825
# -- Generation 147 --
# Max: 16
# Mean: 2.6
# Fitness Max: 35584.0
# Fitness Avg: 1123.405
# -- Generation 148 --
# Max: 11
# Mean: 2.4
# Fitness Max: 15367.0
# Fitness Avg: 615.49
# -- Generation 149 --
# Max: 13
# Mean: 2.445
# Fitness Max: 18759.0
# Fitness Avg: 781.85
# -- Generation 150 --
# Max: 13
# Mean: 2.595
# Fitness Max: 27378.0
# Fitness Avg: 888.23
# -- Generation 151 --
# Max: 11
# Mean: 2.495
# Fitness Max: 17061.0
# Fitness Avg: 765.35
# -- Generation 152 --
# Max: 20
# Mean: 2.39
# Fitness Max: 103200.0
# Fitness Avg: 1416.04
# -- Generation 153 --
# Max: 14
# Mean: 2.435
# Fitness Max: 31948.0
# Fitness Avg: 718.115
# -- Generation 154 --
# Max: 20
# Mean: 2.535
# Fitness Max: 108800.0
# Fitness Avg: 1600.755
# -- Generation 155 --
# Max: 13
# Mean: 2.455
# Fitness Max: 29237.0
# Fitness Avg: 876.81
# -- Generation 156 --
# Max: 11
# Mean: 2.175
# Fitness Max: 11858.0
# Fitness Avg: 572.07
# -- Generation 157 --
# Max: 12
# Mean: 2.34
# Fitness Max: 22022.0
# Fitness Avg: 810.77
# -- Generation 158 --
# Max: 15
# Mean: 2.56
# Fitness Max: 36450.0
# Fitness Avg: 1045.235
# -- Generation 159 --
# Max: 14
# Mean: 2.58
# Fitness Max: 22344.0
# Fitness Avg: 756.52
# -- Generation 160 --
# Max: 12
# Mean: 2.485
# Fitness Max: 21888.0
# Fitness Avg: 805.67
# -- Generation 161 --
# Max: 18
# Mean: 2.675
# Fitness Max: 79704.0
# Fitness Avg: 1361.24
# -- Generation 162 --
# Max: 14
# Mean: 3.02
# Fitness Max: 31556.0
# Fitness Avg: 1306.785
# -- Generation 163 --
# Max: 11
# Mean: 2.8
# Fitness Max: 18029.0
# Fitness Avg: 941.545
# -- Generation 164 --
# Max: 11
# Mean: 2.725
# Fitness Max: 13431.0
# Fitness Avg: 825.4
# -- Generation 165 --
# Max: 16
# Mean: 2.68
# Fitness Max: 39168.0
# Fitness Avg: 1163.11
# -- Generation 166 --
# Max: 15
# Mean: 3.045
# Fitness Max: 43875.0
# Fitness Avg: 1751.115
# -- Generation 167 --
# Max: 12
# Mean: 2.815
# Fitness Max: 19008.0
# Fitness Avg: 1022.625
# -- Generation 168 --
# Max: 22
# Mean: 2.88
# Fitness Max: 106964.0
# Fitness Avg: 1813.215
# -- Generation 169 --
# Max: 16
# Mean: 3.26
# Fitness Max: 43520.0
# Fitness Avg: 1512.02
# -- Generation 170 --
# Max: 14
# Mean: 3.07
# Fitness Max: 25284.0
# Fitness Avg: 1275.06
# -- Generation 171 --
# Max: 19
# Mean: 3.27
# Fitness Max: 68590.0
# Fitness Avg: 2077.465
# -- Generation 172 --
# Max: 14
# Mean: 3.07
# Fitness Max: 29988.0
# Fitness Avg: 1312.03
# -- Generation 173 --
# Max: 16
# Mean: 3.06
# Fitness Max: 34048.0
# Fitness Avg: 1443.83
# -- Generation 174 --
# Max: 19
# Mean: 3.03
# Fitness Max: 55594.0
# Fitness Avg: 1634.88
# -- Generation 175 --
# Max: 14
# Mean: 3.125
# Fitness Max: 36652.0
# Fitness Avg: 1719.905
# -- Generation 176 --
# Max: 20
# Mean: 3.57
# Fitness Max: 69600.0
# Fitness Avg: 2508.4
# -- Generation 177 --
# Max: 14
# Mean: 3.18
# Fitness Max: 27244.0
# Fitness Avg: 1257.865
# -- Generation 178 --
# Max: 15
# Mean: 3.335
# Fitness Max: 30150.0
# Fitness Avg: 1718.385
# -- Generation 179 --
# Max: 21
# Mean: 3.235
# Fitness Max: 94374.0
# Fitness Avg: 2097.84
# -- Generation 180 --
# Max: 23
# Mean: 3.265
# Fitness Max: 130663.0
# Fitness Avg: 2179.56
# -- Generation 181 --
# Max: 12
# Mean: 3.075
# Fitness Max: 19872.0
# Fitness Avg: 1340.875
# -- Generation 182 --
# Max: 16
# Mean: 3.345
# Fitness Max: 42752.0
# Fitness Avg: 1870.95
# -- Generation 183 --
# Max: 16
# Mean: 3.095
# Fitness Max: 42240.0
# Fitness Avg: 1307.605
# -- Generation 184 --
# Max: 15
# Mean: 3.03
# Fitness Max: 40050.0
# Fitness Avg: 1280.64
# -- Generation 185 --
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-056ad9b0d139> in <module>
#      94   scores = []
#      95   for indiv in invalid_ind:
# ---> 96     fitness, score = toolbox.evaluate(indiv, network)
#      97     fitnesses.append(fitness)
#      98     scores.append(score)
#
# <ipython-input-10-056ad9b0d139> in evaluate(indiv, network)
#      31   fitness = 0
#      32   network.setWeightsLinear(indiv)
# ---> 33   fitness,score = run_game(network, display, snake_game, headless=HEADLESS)
#      34   return ((fitness,), score)
#      35
#
# <ipython-input-8-ab3695fef693> in run_game(network, display, snake_game, headless)
#      22                 ]
#      23     #print(inputs)
# ---> 24     output = network.feedForward(inputs)
#      25     decision = np.argmax(output, axis=0)
#      26     if decision == 0:
#
# <ipython-input-9-8e75e04f26ec> in feedForward(self, inputs)
#      23
#      24     # feed input to hidden layer 1
# ---> 25     h1 = np.dot(self.w_i_h1, inputsBias)
#      26     h1 = [self.ReLU(x) for x in h1]              # Activate hidden layer1
#      27
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

gen = logbook.select("gen")
_min = logbook.select("min")
_max = logbook.select("max")
avgs = logbook.select("avg")
stds = logbook.select("std")

plt.rc('axes', labelsize=14)
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)
plt.rc('legend', fontsize=14)

fig, ax1 = plt.subplots()
line1 = ax1.plot(gen, avgs)
ax1.set_xlabel("Generation")
ax1.set_ylabel("Score")

line2 = ax1.plot(gen, _min)
line3 = ax1.plot(gen, _max)

# %%
import pickle
with open("dump.pop", 'wb') as writeFile:
  pickle.dump(pop, writeFile)


bestInd = tools.selBest(pop, 1)[0]

with open("dump.ind", 'wb') as writeFile:
  pickle.dump(bestInd, writeFile)

network.setWeightsLinear(bestInd)

display = DisplayGame(XSIZE, YSIZE)

print(run_game(network, display, snake_game, headless=False))
# Out:
# FINAL score - 11
# (178354, 11)

# %% [markdown]
# Below is what you would use for your evaluation. You would also use it to display your final (pickled and loaded) solution, with headless = False.

# %% [markdown]
# If you have run without headless (i.e. with the display) you will need to reset your kernel to run again. This appears to be an IPython issue with Turtle, but if you have a way to deal with that, do please let me know. You will probable only want to run it one-at-a-time anyway.

# %%
'''
import pickle
with open ("1kgenschanged.ind", 'rb') as readFile:
  bestInd = pickle.load(readFile)

network.setWeightsLinear(bestInd)

display = DisplayGame(XSIZE, YSIZE)

print(run_game(network, display, snake_game, headless=False))
'''
# Out:
# '\nimport pickle\nwith open ("1kgenschanged.ind", \'rb\') as readFile:\n  bestInd = pickle.load(readFile)\n\nnetwork.setWeightsLinear(bestInd)\n\ndisplay = DisplayGame(XSIZE, YSIZE)\n\nprint(run_game(network, display, snake_game, headless=False))\n'
